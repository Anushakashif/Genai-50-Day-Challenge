# %% [markdown]
# ### Comparing Text with Cosine Similarity

# %% [markdown]
# Embeddings convert text into vectors.

# %% [markdown]
# But how do we actually compare two vectors to see if texts are similar?
#
# That's where cosine similarity comes in.

# %%
from google import genai
import os
from dotenv import load_dotenv
import numpy as np

load_dotenv()
API_KEY = os.environ["GOOGLE_API_KEY"]
client = genai.Client(api_key=API_KEY)

# %% [markdown]
# ## Comparing Two Types

# %% [markdown]
# Let's take two sentences that mean same thing but use different words

# %%
text_a = 'The cat sat on the mat'
text_b = 'The feline rested on the rug'

# Get embeddings
embed_a = client.models.embed_content(
    model='gemini-embedding-001',
    contents=text_a
).embeddings[0].values
embed_b = client.models.embed_content(
    model='gemini-embedding-001',
    contents=text_b
).embeddings[0].values

print(f"Text A: {text_a}")
print(f"Text B: {text_b}")
print(f"\n Both have {len(embed_a)} dimensions")
# Out:
# Text A: The cat sat on the mat
# Text B: The feline rested on the rug
#
#  Both have 3072 dimensions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def cosine_similarity(vec1, vec2):
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

similarity = cosine_similarity(embed_a, embed_b)
print(f"Similarity between A and B: {similarity:.4f}")
# Out:
# Similarity between A and B: 0.7691

# %% [markdown]
# ## What is Cosine Similarity?

# %% [markdown]
# Cosine similarity measures the angle between two vectors:
#
# - 1.0 = identical direction (same meaning)
# - 0.0 = perpendicular (unrelated)
# - -1.0 = opposite direction (rare in practice)

# %% [markdown]
# Formula: cos(θ) = (A · B) / (||A|| × ||B||)
#
# - Dot product of the vectors
# - Divided by the product of their magnitudes

# %% [markdown]
# ## Similar vs Different Texts

# %% [markdown]
# Let's compare sentences with similar meaning vs completely different topics.

# %%
sentences = [
    'Machine learning is a subset of AI',
    'ML is part of artificial intelligrnce',
    'The weather is nice today'
]

# Generate embedding
embeddings = []

for s in sentences:
    emb = client.models.embed_content(
        model='gemini-embedding-001',
        contents=s
    ).embeddings[0].values
    
    embeddings.append(emb)
# Compare
print(f"Sentence 1: {sentences[0]}")
print(f"Sentence 1: {sentences[1]}")
print(f"Sentence 1: {sentences[2]}")

print(f"\n 1 vs 2 (similar meaning): {cosine_similarity(embeddings[0], embeddings[1]):.4f}")
print(f"1 vs 3 (different topic):  {cosine_similarity(embeddings[0], embeddings[2]):.4f}")
# Out:
# Sentence 1: Machine learning is a subset of AI
# Sentence 1: ML is part of artificial intelligrnce
# Sentence 1: The weather is nice today
#
#  1 vs 2 (similar meaning): 0.7876
# 1 vs 3 (different topic):  0.5309

# %% [markdown]
# ## Why This Matters

# %% [markdown]
# Cosine similarity is the foundation of:
# 1. Semantic Search — Find documents by meaning, not keywords
# 2. Duplicate Detection — Find similar content
# 3. Clustering — Group related documents
# 4. RAG Systems — Retrieve relevant context for LLMs

# %% [markdown]
# ## Key Takeaways

# %% [markdown]
# 1. Cosine similarity measures how similar two vectors are
# 2. Score of 1.0 = identical meaning, 0.0 = unrelated
# 3. Texts with same meaning but different words score high
# 4. Texts about different topics score low
