# %%
from google import genai
from google.genai import types
import os 
from dotenv import load_dotenv

# %%
load_dotenv()

API_KEY = os.environ['GOOGLE_API_KEY']

client = genai.Client(api_key=API_KEY)
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Hi, my name is anusha. I am  AI/ML Engineer. write a short bio about me'
)
print(response.text)
# Out:
# Okay, Anusha! Here are a few options for a short bio, choose the one that best fits your style or mix and match elements.
#
# ---
#
# **Option 1: Concise & Professional**
#
# > Anusha is an AI/ML Engineer dedicated to designing and implementing intelligent systems that drive innovation. With a strong foundation in machine learning principles, she leverages data to solve complex problems and deliver impactful, data-driven solutions.
#
# ---
#
# **Option 2: Impact-Focused**
#
# > As an AI/ML Engineer, Anusha specializes in transforming complex data into powerful, predictive models. She excels at developing and deploying robust machine learning solutions that tackle real-world challenges and unlock new possibilities for businesses.
#
# ---
#
# **Option 3: Passionate & Forward-Looking**
#
# > Anusha is a passionate AI/ML Engineer thrilled by the potential of artificial intelligence to reshape industries. She thrives on developing cutting-edge machine learning models and algorithms, turning raw data into intelligent systems that push the boundaries of what's possible.
#
# ---
#
# **Option 4: Slightly More Technical (but still short)**
#
# > Anusha is an AI/ML Engineer with expertise in building and optimizing machine learning models across various domains. She is skilled in leveraging advanced algorithms and data pipelines to extract valuable insights and develop scalable AI solutions.
#
# ---
#
# **Remember to customize!**
# You can make it even better by adding:
# *   A specific area of interest (e.g., "with a focus on NLP," "specializing in computer vision," "driving efficiency in fintech").
# *   A key skill/tool you're proud of (e.g., "proficient in Python and TensorFlow," "experienced with cloud AI platforms").
# *   A specific type of impact you want to make.
#
# Choose the one you like best, Anusha!
